# %% [markdown]
# <a href="https://colab.research.google.com/github/Valtern/PCVK_Ganjil_2025/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Image/fatcat.jpeg')
plt.imshow(img)

# %%
img3 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Image/fatcat.jpeg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

#cv.imwrite('/content/drive/MyDrive/PCVK/Image/fatcat_flip.jpg', img5)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros((512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, (384,0), (510,150), (0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=720x1280>

# %%
img6 = img.copy()

fig = plt.figure(figsize=(4,8))
ax = fig.add_subplot(111)
ax.imshow(img6)

# %%
red_green_img = img6.copy()
red_green_img[:, :, 2] = 0

plt.figure(figsize=(2,4))
plt.imshow(red_green_img)


green_blue_img = img6.copy()
green_blue_img[:, :, 0] = 0

plt.figure(figsize=(2,4))
plt.imshow(green_blue_img)

# %%
cropped_img = img6[10:101, 10:101]

plt.figure(figsize=(5, 5))
plt.imshow(cropped_img)
plt.show()

# %%
greenonlyimg = img6.copy()
greenonlyimg[:, :, 0] = 0
greenonlyimg[:, :, 2] = 0

cropgreen = greenonlyimg[5:31, :]

plt.figure(figsize=(12,5))
plt.imshow(cropgreen)
plt.show()

# %%
black_img3=np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img3)

cv.rectangle(black_img3, pt1=(10,10), pt2=(100,100), color=(0,0,255), thickness=5)
plt.imshow(black_img3)

cv.circle(black_img3, center=(100,400), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img3)

cv.line(black_img3, pt1=(0,256), pt2=(511,256), color=(255,255,255), thickness=10)
plt.imshow(black_img3)

cv.ellipse(black_img3, center=(100,256), axes=(100,50), angle=0, startAngle=0, endAngle=360, color=(255,0,0), thickness=5)
plt.imshow(black_img3)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img3, text='iloveopencv2', org=(1,150), fontFace=font, fontScale=1, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img3)

# %%
black_img3 = cv.flip(black_img3, 1)
plt.imshow(black_img3)

# %%
ktm = cv.imread('/content/drive/MyDrive/PCVK/Image/ktm.jpg')

ktm = cv.cvtColor(ktm, cv.COLOR_BGR2RGB)


cv.rectangle(ktm, pt1=(90,110), pt2=(240,270), color=(0,0,255), thickness=-1)
cv.circle(ktm, center=(168,190), radius=50, color=(255,0,0), thickness=-1)
plt.imshow(ktm)

# %%
im7 = img.copy()
size = im7.shape
print(size)

im7 = cv.cvtColor(im7, cv.COLOR_BGR2RGB)

im7[:, :, 0] = 0
im7[:, :, 2] = 0

cv.rectangle(im7, pt1=(259,1000), pt2=(0,1280), color=(0,0,255), thickness=-1)
plt.imshow(im7)


print("id assume kitten is the previous image that we used for this practicum, we havent used image such as lena/couple/sailboat or other things")
# Out:
# (1280, 720, 3)
# id assume kitten is the previous image that we used for this practicum, we havent used image such as lena/couple/sailboat or other things

# %%
im8 = im7.copy()

font = cv.FONT_HERSHEY_SIMPLEX

cv.putText(im8, text='fat epic cat', org=(0,200), fontFace=font, fontScale=3, color=(255,0,255), thickness=2, lineType=cv.LINE_AA )

plt.imshow(im8)

# %%
ktp = cv.imread('/content/drive/MyDrive/PCVK/Image/ktp.jpg')

ktp = cv.cvtColor(ktp, cv.COLOR_BGR2RGB)


size = ktp.shape
print(size)

cv.rectangle(ktp, pt1=(410,460), pt2=(530,420), color=(255,0,0), thickness=-1)

plt.imshow(ktp)
# Out:
# (1045, 1500, 3)
